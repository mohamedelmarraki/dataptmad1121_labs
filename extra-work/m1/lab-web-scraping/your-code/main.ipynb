# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here

response = requests.get(url)
print(type(response))
html = response.content
print(type(html))
# Out:
# <class 'requests.models.Response'>
# <class 'bytes'>

# %%
soup = BeautifulSoup(response, "html.parser")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
parse_tags = set([tag.name for tag in soup.find_all(True)])
parse_tags
# Out:
# {'a',
#  'article',
#  'body',
#  'button',
#  'circle',
#  'clipboard-copy',
#  'details',
#  'details-dialog',
#  'details-menu',
#  'div',
#  'filter-input',
#  'form',
#  'g-emoji',
#  'h1',
#  'head',
#  'header',
#  'html',
#  'img',
#  'include-fragment',
#  'input',
#  'label',
#  'li',
#  'link',
#  'main',
#  'meta',
#  'nav',
#  'p',
#  'path',
#  'script',
#  'span',
#  'summary',
#  'svg',
#  'template',
#  'title',
#  'ul'}

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
element1=soup.find_all("div", {"class":"Box"})
element1
# Out:
# [<div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#  <ul class="d-none js-jump-to-suggestions-template-container">
#  <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
element2=soup.find_all("h1", {"class": "h3 lh-condensed"})
element2
# Out:
# [<h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":393243,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="51494e5dac5a49f064fd1fae8c176ba691ca6538effdede12fa1f6c1b635647b" data-view-component="true" href="/antonbabenko">
#              Anton Babenko
#  </a> </h1>,
#  <h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":4060,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="10aacb8e8dd86b005606b4e182e17bc5864287061b6f57b69fad7f771a3d8e95" data-view-component="true" href="/derailed">
#              Fernand Galiana
# ...

# %%
dev = []
for i in element2:
    dev.append((i.text).strip())
dev
# Out:
# ['Anton Babenko',
#  'Fernand Galiana',
#  'Joe Chen',
#  'Alex Goodman',
#  'kezhenxu94',
#  'Georgios Konstantopoulos',
#  'Zachary Rice',
#  'Steve Macenski',
#  'Asim Aslam',
#  'Evan Wallace',
#  'Gajus Kuizinas',
#  'Eliza Weisman',
#  'John Lindquist',
#  'Rijk van Zanten',
#  'Robert Mosolgo',
#  'Mariusz Nowak',
#  'Casey Davenport',
#  'Rich Harris',
#  'R.I.Pienaar',
#  'Carlos Alexandro Becker',
#  'Shivam Mathur',
#  'Chocobozzz',
#  'Alex Potsides',
#  'Rico Sta. Cruz',
#  'Stephen Celis']

# %%
element3 = soup.find_all("p", {"class": "f4 text-normal mb-1"})
element3
# Out:
# [<p class="f4 text-normal mb-1">
#  <a class="Link--secondary" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":393243,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="51494e5dac5a49f064fd1fae8c176ba691ca6538effdede12fa1f6c1b635647b" data-view-component="true" href="/antonbabenko">
#                antonbabenko
#  </a> </p>,
#  <p class="f4 text-normal mb-1">
# ...

# %%
users = []
for i in element3:
    users.append((i.text).strip())
users
# Out:
# ['antonbabenko',
#  'derailed',
#  'unknwon',
#  'wagoodman',
#  'kezhenxu94',
#  'gakonst',
#  'zricethezav',
#  'SteveMacenski',
#  'asim',
#  'evanw',
#  'gajus',
#  'hawkw',
#  'johnlindquist',
#  'rijkvanzanten',
#  'rmosolgo',
#  'medikoo',
#  'caseydavenport',
#  'Rich-Harris',
#  'ripienaar',
#  'caarlos0',
#  'shivammathur',
#  'achingbrain',
#  'rstacruz',
#  'stephencelis']

# %%
users = ['({0})'.format(i) for i in users]
users
# Out:
# ['(antonbabenko)',
#  '(derailed)',
#  '(unknwon)',
#  '(wagoodman)',
#  '(kezhenxu94)',
#  '(gakonst)',
#  '(zricethezav)',
#  '(SteveMacenski)',
#  '(asim)',
#  '(evanw)',
#  '(gajus)',
#  '(hawkw)',
#  '(johnlindquist)',
#  '(rijkvanzanten)',
#  '(rmosolgo)',
#  '(medikoo)',
#  '(caseydavenport)',
#  '(Rich-Harris)',
#  '(ripienaar)',
#  '(caarlos0)',
#  '(shivammathur)',
#  '(achingbrain)',
#  '(rstacruz)',
#  '(stephencelis)']

# %%
nick =[]
for (item1,item2) in zip(dev,users):
    nick.append(item1 + ' ' + item2)
nick
# Out:
# ['Anton Babenko (antonbabenko)',
#  'Fernand Galiana (derailed)',
#  'Joe Chen (unknwon)',
#  'Alex Goodman (wagoodman)',
#  'kezhenxu94 (kezhenxu94)',
#  'Georgios Konstantopoulos (gakonst)',
#  'Zachary Rice (zricethezav)',
#  'Steve Macenski (SteveMacenski)',
#  'Asim Aslam (asim)',
#  'Evan Wallace (evanw)',
#  'Gajus Kuizinas (gajus)',
#  'Eliza Weisman (hawkw)',
#  'John Lindquist (johnlindquist)',
#  'Rijk van Zanten (rijkvanzanten)',
#  'Robert Mosolgo (rmosolgo)',
#  'Mariusz Nowak (medikoo)',
#  'Casey Davenport (caseydavenport)',
#  'Rich Harris (Rich-Harris)',
#  'R.I.Pienaar (ripienaar)',
#  'Carlos Alexandro Becker (caarlos0)',
#  'Shivam Mathur (shivammathur)',
#  'Chocobozzz (achingbrain)',
#  'Alex Potsides (rstacruz)',
#  'Rico Sta. Cruz (stephencelis)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
response = requests.get(url)
html = response.content
parsed_html = BeautifulSoup(html, "html.parser")
parsed_html
# Out:
# <!DOCTYPE html>
#
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
trend = parsed_html.find_all("h1", {"class": "h3 lh-condensed"})
trend
# Out:
# [<h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_REPOSITORIES_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/trending/python?since=daily","user_id":null}}' data-hydro-click-hmac="2fa3c30f3e2296f6cda66eed6bf4dbb4d3ddfa27cc31b3023389b4300a84d7a6" data-view-component="true" href="/tiangolo/fastapi">
#  <svg aria-hidden="true" class="octicon octicon-repo mr-1 color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
trend1= list()
for i in trend:
    trend1.append((i.text).strip())
    
trend1
# Out:
# ['tiangolo /\n\n      fastapi',
#  'ytdl-org /\n\n      youtube-dl',
#  'jfrog /\n\n      log4j-tools',
#  'fox-it /\n\n      log4j-finder',
#  'niubiqigai /\n\n      turtle',
#  'psf /\n\n      black',
#  'PrefectHQ /\n\n      prefect',
#  'kakaobrain /\n\n      minDALL-E',
#  'luminoleon /\n\n      epicgames-claimer',
#  'saleor /\n\n      saleor',
#  'python-poetry /\n\n      poetry',
#  'PaddlePaddle /\n\n      PaddleClas',
#  'gto76 /\n\n      python-cheatsheet',
#  'facebookresearch /\n\n      pytorch3d',
#  'zulip /\n\n      zulip',
#  'encode /\n\n      django-rest-framework',
#  'yt-dlp /\n\n      yt-dlp',
#  'IAmPara0x /\n\n      Yuno',
#  'PaddlePaddle /\n\n      PaddleOCR',
#  'Pycord-Development /\n\n      pycord',
#  'PaddlePaddle /\n\n      PaddleSpeech',
#  'facebookresearch /\n\n      moco',
#  'AdnanHodzic /\n\n      auto-cpufreq',
#  'qubvel /\n\n      segmentation_models.pytorch',
#  'apple /\n\n      ARKitScenes']

# %%
[i.replace(' ', '').split('\n\n')[1] for i in trend1]
# Out:
# ['fastapi',
#  'youtube-dl',
#  'log4j-tools',
#  'log4j-finder',
#  'turtle',
#  'black',
#  'prefect',
#  'minDALL-E',
#  'epicgames-claimer',
#  'saleor',
#  'poetry',
#  'PaddleClas',
#  'python-cheatsheet',
#  'pytorch3d',
#  'zulip',
#  'django-rest-framework',
#  'yt-dlp',
#  'Yuno',
#  'PaddleOCR',
#  'pycord',
#  'PaddleSpeech',
#  'moco',
#  'auto-cpufreq',
#  'segmentation_models.pytorch',
#  'ARKitScenes']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
response = requests.get(url)
html = response.content
parsed_html = BeautifulSoup(html, "html.parser")
parsed_html
image = parsed_html.find_all("a", {"class": "image"})
for i in image:
    print(i['href']+ '\n')
# Out:
# /wiki/File:Walt_Disney_1946.JPG
#
# /wiki/File:Walt_Disney_1942_signature.svg
#
# /wiki/File:Walt_Disney_envelope_ca._1921.jpg
#
# /wiki/File:Trolley_Troubles_poster.jpg
#
# /wiki/File:Steamboat-willie.jpg
#
# /wiki/File:Walt_Disney_1935.jpg
#
# /wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg
#
# /wiki/File:Disney_drawing_goofy.jpg
#
# /wiki/File:DisneySchiphol1951.jpg
#
# /wiki/File:WaltDisneyplansDisneylandDec1954.jpg
#
# /wiki/File:Walt_disney_portrait_right.jpg
#
# /wiki/File:Walt_Disney_Grave.JPG
#
# /wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg
#
# /wiki/File:Disney_Oscar_1953_(cropped).jpg
#
# /wiki/File:Disney1968.jpg
#
# /wiki/File:Disneyland_Resort_logo.svg
#
# /wiki/File:Animation_disc.svg
#
# /wiki/File:P_vip.svg
#
# /wiki/File:Magic_Kingdom_castle.jpg
#
# /wiki/File:Video-x-generic.svg
#
# /wiki/File:Flag_of_Los_Angeles_County,_California.svg
#
# /wiki/File:Blank_television_set.svg
#
# /wiki/File:Flag_of_the_United_States.svg

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
import re

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
wiki = requests.get(url)
wiki = wiki.content
wiki_parsed = BeautifulSoup(wiki, "html.parser")
element = wiki_parsed.find_all("a",{'href':re.compile('/wiki/Python')})

for i in element:
    print(i['href']+ '\n')
# Out:
# https://en.wiktionary.org/wiki/Python
#
# /wiki/Pythonidae
#
# /wiki/Python_(genus)
#
# /wiki/Python_(programming_language)
#
# /wiki/Python_of_Aenus
#
# /wiki/Python_(painter)
#
# /wiki/Python_of_Byzantium
#
# /wiki/Python_of_Catana
#
# /wiki/Python_Anghelo
#
# /wiki/Python_(Efteling)
#
# /wiki/Python_(Busch_Gardens_Tampa_Bay)
#
# /wiki/Python_(Coney_Island,_Cincinnati,_Ohio)
#
# /wiki/Python_(automobile_maker)
#
# /wiki/Python_(Ford_prototype)
#
# /wiki/Python_(missile)
#
# /wiki/Python_(nuclear_primary)
#
# /wiki/Python_(film)
#
# /wiki/Python_(mythology)
#
# /wiki/Python_(Monty)_Pictures
#
# /wiki/Python
#
# /wiki/Python
#
# https://af.wikipedia.org/wiki/Python
#
# https://als.wikipedia.org/wiki/Python
#
# https://az.wikipedia.org/wiki/Python
#
# https://be.wikipedia.org/wiki/Python
#
# https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)
#
# https://da.wikipedia.org/wiki/Python
#
# https://de.wikipedia.org/wiki/Python
#
# https://eu.wikipedia.org/wiki/Python_(argipena)
#
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
us_code = requests.get(url)
us_code = us_code.content
us_code_parsed = BeautifulSoup(us_code, "html.parser")
element = us_code_parsed.find_all("div", {"class": "usctitle"})
element
us= list()
for i in element:
    us.append((i.text).strip())

print(len(us))
us
# Out:
# 55
# ['All titles in the format selected compressed into a zip archive.',
#  '',
#  'Title 1 - General Provisions ٭',
#  'Title 2 - The Congress',
#  'Title 3 - The President ٭',
#  'Title 4 - Flag and Seal, Seat of Government, and the States ٭',
#  'Title 5 - Government Organization and Employees ٭',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 9 - Arbitration ٭',
#  'Title 10 - Armed Forces ٭',
#  'Title 11 - Bankruptcy ٭',
#  'Title 12 - Banks and Banking',
#  'Title 13 - Census ٭',
#  'Title 14 - Coast Guard ٭',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights ٭',
#  'Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 19 - Customs Duties',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways ٭',
#  'Title 24 - Hospitals and Asylums',
#  'Title 25 - Indians',
# ...

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
fbi = requests.get(url)
fbi = fbi.content
fbi_parsed = BeautifulSoup(fbi, "html.parser")
element = fbi_parsed.find_all("h3", {"class": "title"})
fbi_wanted= list()
for i in element:
    fbi_wanted.append((i.text).strip())
fbi_wanted
# Out:
# ['JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'OCTAVIANO JUAREZ-CORRO',
#  'RAFAEL CARO-QUINTERO',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'EUGENE PALMER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here
eq = requests.get(url)
eq = eq.content
eq_parsed = BeautifulSoup(eq, "html.parser")
element = eq_parsed.find_all("tbody",{"id": "tbody"})
for i in element:
    print(i.get_text())
# Out:
# earthquake2021-12-18   16:19:56.906min ago38.83 N  122.81 W  2Md2.1 NORTHERN CALIFORNIA2021-12-18 16:21
# earthquake2021-12-18   16:15:30.010min ago22.22 S  68.57 W  113 M2.8 ANTOFAGASTA, CHILE2021-12-18 16:24
# earthquake2021-12-18   16:10:03.716min ago19.03 N  155.40 W  34Md2.1 ISLAND OF HAWAII, HAWAII2021-12-18 16:13
# earthquake2021-12-18   15:57:54.028min ago35.45 N  3.62 W  20ML2.5 STRAIT OF GIBRALTAR2021-12-18 16:04
# earthquake2021-12-18   15:38:33.047min ago0.53 N  99.70 E  10 M3.3 NORTHERN SUMATRA, INDONESIA2021-12-18 15:45
# earthquake2021-12-18   15:25:32.61hr 00min ago34.76 N  97.55 W  2ML2.8 OKLAHOMA2021-12-18 15:31
# earthquake2021-12-18   15:23:23.11hr 02min ago35.60 N  3.62 W  10ML2.5 STRAIT OF GIBRALTAR2021-12-18 15:44
# Fearthquake2021-12-18   15:12:55.11hr 13min ago37.70 N  1.69 W  2ML2.6 SPAIN2021-12-18 15:32
# earthquake2021-12-18   15:05:02.01hr 21min ago7.28 S  121.18 E  10 M3.8 FLORES SEA2021-12-18 15:10
# ...

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
twitter1 = requests.get(url)
twitter1
# Out:
# <Response [200]>

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
twitter2 = requests.get(url)
twitter2
# Out:
# <Response [200]>

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here
wp = requests.get(url)
wp = wp.content
wp1 = BeautifulSoup(wp, "html.parser")
nameList = wp1.find_all('a', {'class' : 'link-box'})
for name in nameList:
    print(name.get_text())
# Out:
# English
# 6 383 000+ articles
#
#
# 日本語
# 1 292 000+ 記事
#
#
# Русский
# 1 756 000+ статей
#
#
# Deutsch
# 2 617 000+ Artikel
#
#
# Español
# 1 717 000+ artículos
#
#
# Français
# 2 362 000+ articles
#
#
# 中文
# 1 231 000+ 條目
#
#
# Italiano
# 1 718 000+ voci
#
#
# Português
# 1 074 000+ artigos
#
#
# Polski
# 1 490 000+ haseł

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here
govuk = requests.get(url)
govuk = govuk.content
gov = BeautifulSoup(govuk, "html.parser")
data_uk = gov.find_all('a', {'class' : 'govuk-link'})
for name in data_uk:
    print(name.get_text())
# Out:
# cookies to collect information
# View cookies
# change your cookie settings
# feedback
# Business and economy
# Crime and justice
# Defence
# Education
# Environment
# Government
# Government spending
# Health
# Mapping
# Society
# Towns and cities
# Transport
# Digital service performance
# Government reference data

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
native = requests.get(url)
native = native.content
natv = BeautifulSoup(govuk, "html.parser")
nativelang = natv.find_all('a', {'href':'/wiki'})
for name in nativelang:
    print(name.get_text())

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
